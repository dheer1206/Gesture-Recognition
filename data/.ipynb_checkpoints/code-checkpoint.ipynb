# %%
import tensorflow as tf

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import matplotlib.image as myimg
from PIL import Image
# %matplotlib inline

# %%
import os

# %%
os.listdir()
# Out:
# ['Point', 'code.ipynb', 'Five', 'A', 'C', 'B', 'V', '.ipynb_checkpoints']

# %%
pt = list(os.listdir('Point'))
for i in pt :
    im = Image.open("Point/" + i)
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=384x288 at 0x7F14F4576208>
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=78x90 at 0x7F14F4576240>
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=66x78 at 0x7F14F4576208>
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=66x76 at 0x7F14F4576240>
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=155x155 at 0x7F14F4576208>
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=68x80 at 0x7F14F4576240>
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=80x66 at 0x7F14F4576208>
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=90x78 at 0x7F14F4576240>
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=88x76 at 0x7F14F4576208>
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=384x288 at 0x7F14F4576240>
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=76x88 at 0x7F14F4576320>
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=82x70 at 0x7F14F4576358>
# ...
